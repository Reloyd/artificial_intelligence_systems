# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
import psycopg2

conn = psycopg2.connect(
    host="localhost",
    port=5432,
    database="nba-postgres",
    user="postgresql",
    password="12345"
)

# читаем таблицу в DataFrame
df = pd.read_sql_query("SELECT * FROM game;", conn)

conn.close()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[2], line 3
#       1 import psycopg2
# ----> 3 conn = psycopg2.connect(
#       4     host="localhost",
#       5     port=5432,
#       6     database="nba-postgres",
#       7     user="postgresql",
#       8     password="12345"
#       9 )
#      11 # читаем таблицу в DataFrame
#      12 df = pd.read_sql_query("SELECT * FROM game;", conn)
#
# File c:\anaconda\Lib\site-packages\psycopg2\__init__.py:135, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     132     kwasync['async_'] = kwargs.pop('async_')
#     134 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 135 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     136 if cursor_factory is not None:
#     137     conn.cursor_factory = cursor_factory
#
# ...
